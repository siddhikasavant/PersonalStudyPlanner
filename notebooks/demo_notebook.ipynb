# %%
# %cd ..
# Out:
# d:\PersonalStudyPlanner

# %%
import os
os.getcwd()
# Out:
# 'd:\\PersonalStudyPlanner'

# %%
from agents.main_agent import MainAgent

# %%
agent = MainAgent()

subjects = ["Math", "Physics", "English", "Chemistry"]
for sub in subjects:
    agent.add_subject(sub)

# %%
schedule = agent.create_schedule(subjects, "2025-12-01")
print("Generated Schedule:")
for s in schedule:
    print(s)
# Out:
# Generated Schedule:
# {'subject': 'Math', 'date': '2025-12-01', 'duration': 2}
# {'subject': 'Physics', 'date': '2025-12-02', 'duration': 2}
# {'subject': 'English', 'date': '2025-12-03', 'duration': 2}
# {'subject': 'Chemistry', 'date': '2025-12-04', 'duration': 2}

# %%
sessions = agent.view_schedule()
print("\nStored Sessions in DB:")
for s in sessions:
    print(s)
# Out:
# Stored Sessions in DB:
# (1, 'Math', '2025-12-01', 2, 0)
# (2, 'Physics', '2025-12-02', 2, 0)
# (3, 'English', '2025-12-03', 2, 0)
# (4, 'Math', '2025-12-01', 2, 0)
# (5, 'Physics', '2025-12-02', 2, 0)
# (6, 'English', '2025-12-03', 2, 0)
# (7, 'Math', '2025-12-01', 2, 0)
# (8, 'Physics', '2025-12-02', 2, 0)
# (9, 'English', '2025-12-03', 2, 0)
# (10, 'Chemistry', '2025-12-04', 2, 0)
# (11, 'Math', '2025-12-01', 2, 0)
# (12, 'Physics', '2025-12-02', 2, 0)
# (13, 'English', '2025-12-03', 2, 0)
# (14, 'Chemistry', '2025-12-04', 2, 0)

# %%
agent.close()
